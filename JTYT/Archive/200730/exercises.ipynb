# %% [markdown]
# # Dictionary & manipulations
#
# 1. Convert the dictionary below into a dataframe:
#
# ```
# {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie'],
#             "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod'],
#             "type": ['grass', 'fire', 'water', 'bug'],
#             "hp": [45, 39, 44, 45],
#             "pokedex": ['yes', 'no','yes','no']}
# ```
#
# 1. Re-arrange the columns into name, type, hp, evolution, pokedex
# ```
# 	name	type	hp	evolution	pokedex
# 0	Bulbasaur	grass	45	Ivysaur	yes
# 1	Charmander	fire	39	Charmeleon	no
# 2	Squirtle	water	44	Wartortle	yes
# 3	Caterpie	bug	45	Metapod	no
# ```
# 1. Add another column called owner and fill with whatever names you like
#
# 1. Create a similar dataframe as above with the dictionaries below:
# ```
# data1 = {'index': [0, 1, 2, 3],
#           'columns': ['name', 'evolution', 'type', 'hp', 'pokedex'],
#           'data': [['Bulbasaur', 'Ivysaur', 'grass', 45, 'yes'],
#                     ['Charmander', 'Charmeleon', 'fire', 39, 'no'],
#                     ['Squirtle', 'Wartortle', 'water', 44, 'yes'],
#                     ['Caterpie', 'Metapod', 'bug', 45, 'no']]}
# ```
# ```
# data2 = [{'name': 'Bulbasaur',
#           'evolution': 'Ivysaur',
#           'type': 'grass',
#           'hp': 45,
#           'pokedex': 'yes'},
#         {'name': 'Charmander',
#           'evolution': 'Charmeleon',
#           'type': 'fire',
#           'hp': 39,
#           'pokedex': 'no'},
#         {'name': 'Squirtle',
#           'evolution': 'Wartortle',
#           'type': 'water',
#           'hp': 44,
#           'pokedex': 'yes'},
#         {'name': 'Caterpie',
#           'evolution': 'Metapod',
#           'type': 'bug',
#           'hp': 45,
#           'pokedex': 'no'}]
# ```
# ```
# data3 = {0: {'name': 'Bulbasaur',
#             'evolution': 'Ivysaur',
#             'type': 'grass',
#             'hp': 45,
#             'pokedex': 'yes'},
#           1: {'name': 'Charmander',
#             'evolution': 'Charmeleon',
#             'type': 'fire',
#             'hp': 39,
#             'pokedex': 'no'},
#           2: {'name': 'Squirtle',
#             'evolution': 'Wartortle',
#             'type': 'water',
#             'hp': 44,
#             'pokedex': 'yes'},
#           3: {'name': 'Caterpie',
#             'evolution': 'Metapod',
#             'type': 'bug',
#             'hp': 45,
#             'pokedex': 'no'}}
# ```

# %% [markdown]
# # From lists of lists
#
# ```
# lst1 = [a1, b1, c1, d1, e1, f1]
# lst2 = [a2, b2, c2, d2, e2, f2]
# lst3 = [a3, b3, c3, d3, e3, f3]
# ```
#
# 1. Convert the lists into a DataFrame with 3 columns - a, b, c, d, e, f
# 1. Convert the lists into a a Dataframe with the letters and numbers transposed - columns as 1, 2, 3
