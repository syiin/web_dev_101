# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import numpy as np

# %%
import my_utils

my_utils.add_2_numbers(4, 2)
# Out:
# 6

# %%
from my_utils import add_2_numbers

add_2_numbers(2, 3)
# Out:
# 5

# %%
import my_utils as myu

myu.add_2_numbers(2,2)
# Out:
# 4

# %%
from my_utils import *

df = pd.read_csv('../data/ETFs/spy.us.txt')
get_technical_indicators(df, 'Close')
# Out:
#             Date    Open     High      Low   Close     Volume  OpenInt  \
# 0     2005-02-25  104.77  106.000  104.680  105.79   70221808        0
# 1     2005-02-28  105.55  105.680  104.560  105.08   79695344        0
# 2     2005-03-01  105.22  105.870  105.220  105.62   54607412        0
# 3     2005-03-02  105.21  106.220  105.100  105.57   73733090        0
# 4     2005-03-03  105.99  106.200  105.150  105.61   71286823        0
# 5     2005-03-04  106.31  107.010  106.100  106.93   64483624        0
# 6     2005-03-07  106.86  107.380  106.620  106.97   50288014        0
# 7     2005-03-08  106.87  107.150  106.360  106.55   51274973        0
# 8     2005-03-09  106.25  106.520  105.380  105.39   84491113        0
# 9     2005-03-10  105.40  105.850  104.890  105.62   74962248        0
# 10    2005-03-11  105.88  106.040  104.660  104.88   66729930        0
# 11    2005-03-14  104.89  105.560  104.780  105.54   41713280        0
# ...

# %% [markdown]
# Packages are modules in a folder with an init

# %%
from mypkg import my_utils

# %%
my_utils.divide_by_const(3)
# Out:
# 0.3

# %%
my_utils.multiply_by_const(3)
# Out:
# 30

# %% [markdown]
# Slicing datetime indexed dataframes

# %%
df.index = df.Date

# %%
df['2005-03-11': '2005-03-15']
# Out:
#                   Date    Open    High     Low   Close    Volume  OpenInt  \
# Date
# 2005-03-11  2005-03-11  105.88  106.04  104.66  104.88  66729930        0
# 2005-03-14  2005-03-14  104.89  105.56  104.78  105.54  41713280        0
# 2005-03-15  2005-03-15  105.78  105.82  104.60  104.65  71730138        0
#
#                    ma7  ma21       26ema       12ema      MACD  20sd  \
# Date
# 2005-03-11  105.992857   NaN  105.809111  105.768525 -0.040586   NaN
# 2005-03-14  105.982857   NaN  105.776047  105.727894 -0.048152   NaN
# 2005-03-15  105.657143   NaN  105.644130  105.540731 -0.103400   NaN
#
#             upper_band  lower_band         ema  momentum  log_momentum
# Date
# 2005-03-11         NaN         NaN  105.147254    103.88      4.643236
# 2005-03-14         NaN         NaN  105.409085    104.54      4.649570
# 2005-03-15         NaN         NaN  104.903028    103.65      4.641020
