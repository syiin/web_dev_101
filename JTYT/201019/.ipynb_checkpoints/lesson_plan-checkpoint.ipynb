# %% [markdown]
# https://stats.stackexchange.com/questions/2691/making-sense-of-principal-component-analysis-eigenvectors-eigenvalues

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

plt.style.use(['dark_background'])

# %%
n = 1000
mu, sigma = 0, 0.1 # mean and standard deviation
x1 = np.random.normal(mu, sigma, n)
x2 = 2 * x1 + np.random.normal(mu, sigma, n)

# %%
x1.shape, x2.shape
# Out:
# ((1000,), (1000,))

# %%
plt.scatter(x1, x2)

# %%
mu1 = x1.mean()
mu2 = x2.mean()

# %%
covar_x1x2 = (np.sum((x1 - mu1) * (x2 - mu2))) / (n -1)

# %%
covar_x1x2
# Out:
# 0.020958937114851105

# %% [markdown]
# # Calculate Eigenvectors and eigenvalues of the covariance matrix
#
# 1. The eigenvectors are perpendicular to each other
# 1. Notice one of the eigenvectors goes through the data like a line of best fit
# 1. The other shows us that the data follows the main line but is off by some amount
# 1. The eigenvector with the highest eigenvalue is the principal component of the dataset

# %%
X = np.stack((x1, x2), axis=0)
covar_x1x2 = np.cov(X) 
print(covar_x1x2)
# Out:
# [[0.01044873 0.02095894]
#  [0.02095894 0.05272143]]

# %%
e_val, e_vec = np.linalg.eig(covar_x1x2)

# %%
e_val, e_vec
# Out:
# (array([0.00181895, 0.06135121]),
#  array([[-0.92468391, -0.38073568],
#         [ 0.38073568, -0.92468391]]))

# %%
e_vec[:,0]@e_vec[:,1] #they are perpendicular
# Out:
# 0.0

# %%
e_vec[:,1]
# Out:
# array([-0.38073568, -0.92468391])

# %%
np.linalg.norm(e_vec[:,0]) #it is a unit vector
# Out:
# 1.0

# %%
plt.scatter(x1, x2)
plt.quiver(0, 0, e_vec[:,0], e_vec[:,1], color=['r','b','g'], scale=5)
plt.show()

# %%
principal_component = e_vec[:, np.argmax(e_val)]
principal_component
# Out:
# array([-0.38073568, -0.92468391])

# %% [markdown]
# # Deriving a new dataset

# %%
mean_adj_data = X - np.expand_dims(np.array([mu1, mu2]), axis=1)

# %%
e_vec.shape
# Out:
# (2, 2)

# %%
mean_adj_data.shape
# Out:
# (2, 1000)

# %%
final_data = e_vec @ mean_adj_data

# %%
final_data
# Out:
# array([[ 0.08049686,  0.10785626,  0.45674823, ..., -0.30151716,
#         -0.30696794,  0.31881587],
#        [ 0.17954896,  0.115541  ,  0.50954467, ..., -0.24699813,
#         -0.38057355,  0.29574814]])

# %% [markdown]
# # Scikit Learn

# %%
from sklearn import datasets
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
# Sepal Length, Sepal Width, Petal Length and Petal Width.
X[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
pca = PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

# %% [markdown]
# The principal components

# %%
pca.components_.T[:,0]
# Out:
# array([ 0.36138659, -0.08452251,  0.85667061,  0.3582892 ])

# %% [markdown]
# Explained variance is the proportion of variance along the axis of the components from the dataset

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.92461872 0.05306648 0.01710261]

# %%
print(pca.singular_values_)
# Out:
# [25.09996044  6.01314738  3.41368064]

# %%
X2D = pca.fit_transform(X)

# %%
X2D
# Out:
# array([[-2.68412563,  0.31939725, -0.02791483],
#        [-2.71414169, -0.17700123, -0.21046427],
#        [-2.88899057, -0.14494943,  0.01790026],
#        [-2.74534286, -0.31829898,  0.03155937],
#        [-2.72871654,  0.32675451,  0.09007924],
#        [-2.28085963,  0.74133045,  0.16867766],
#        [-2.82053775, -0.08946138,  0.25789216],
#        [-2.62614497,  0.16338496, -0.02187932],
#        [-2.88638273, -0.57831175,  0.02075957],
#        [-2.6727558 , -0.11377425, -0.19763272],
#        [-2.50694709,  0.6450689 , -0.07531801],
#        [-2.61275523,  0.01472994,  0.10215026],
#        [-2.78610927, -0.235112  , -0.20684443],
#        [-3.22380374, -0.51139459,  0.06129967],
#        [-2.64475039,  1.17876464, -0.15162752],
#        [-2.38603903,  1.33806233,  0.2777769 ],
#        [-2.62352788,  0.81067951,  0.13818323],
#        [-2.64829671,  0.31184914,  0.02666832],
#        [-2.19982032,  0.87283904, -0.12030552],
#        [-2.5879864 ,  0.51356031,  0.21366517],
# ...

# %% [markdown]
# Choosing the right number of components

# %%
cumsum = np.cumsum(pca.explained_variance_ratio_)
#how many components will it take before the summed explained variance is greater than 95%
d = np.argmax(cumsum >= 0.95 ) + 1

# %%
d
# Out:
# 2

# %% [markdown]
# Instead of calculating how many components we want, we ask for how many components will explain 95% of the variance

# %%
pca = PCA(n_components=0.95)
X2D = pca.fit_transform(X)

# %%
X2D.shape
# Out:
# (150, 2)

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])

plt.show()

# %%
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot sepal width vs sepal length
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# # Kernel PCA

# %% [markdown]
# What is the radial basis function?
# Any function such that $ f(x) = f(||x - c||) $
#
# It's used for all sorts of things but interpolation of data is common as per below

# %%
import numpy as np
from scipy.interpolate import Rbf

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib import cm

# 2-d tests - setup scattered data
x = np.random.rand(100)*4.0-2.0
y = np.random.rand(100)*4.0-2.0
z = x*np.exp(-x**2-y**2)
ti = np.linspace(-2.0, 2.0, 100)
XI, YI = np.meshgrid(ti, ti)

# use RBF
rbf = Rbf(x, y, z, epsilon=2)
ZI = rbf(XI, YI)

# plot the result
n = plt.Normalize(-2., 2.)
plt.subplot(1, 1, 1)
plt.pcolor(XI, YI, ZI, cmap=cm.jet)
plt.scatter(x, y, 100, z, cmap=cm.jet)
plt.title('RBF interpolation - multiquadrics')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.colorbar()
plt.savefig('rbf2d.png')

# %% [markdown]
# It is also commonly use as part of the "kernel trick" - instead of higher order polynomials (see images) it has only one parameter. It also happens to just work generally well in practice.
#
# Besides that:
#
# It is a stationary kernel, which means that it is invariant to translation. Suppose you are computing K(x,y). A stationary kernel will yield the same value K(x,y) for K(x+c,y+c), where c may be vector-valued of dimension to match the inputs. For the RBF, this is accomplished by working on the difference of the two vectors. For contrast, note that the linear kernel does not have the stationarity property.
#
# The single-parameter version of the RBF kernel has the property that it is isotropic, i.e. the scaling by γ occurs the same amount in all directions. This can be easily generalized, though, by slightly tweaking the RBF kernel to K(x,y)=exp(−(x−y)′Γ(x−y)) where Γ is a p.s.d. matrix.
#
# Another property of the RBF kernel is that it is infinitely smooth. This is aesthetically pleasing, and somewhat satisfying visually, but perhaps it is not the most important property. Compare the RBF kernel to the Matern kernel and you'll see that there some kernels are quite a bit more jagged!
#
# https://stats.stackexchange.com/questions/172554/why-is-rbf-kernel-used-in-svm#:~:text=I%20think%20the%20good%20reasons,as%20opposed%20to%20other%20kernels.&text=Indeed%2C%20it%20is%20easy%2C%20with,%CE%B3%20to%20a%20large%20value).

# %%
from sklearn.decomposition import KernelPCA

rbf_pca = KernelPCA(n_components=2, kernel="rbf", gamma=0.04)
X_reduced = rbf_pca.fit_transform(X)

# %% [markdown]
# Grid search

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ("kpca",KernelPCA(n_components=2)),
    ("log_reg",LogisticRegression())
    ])

param_grid=[{
"kpca__gamma":np.linspace(0.03,0.05,10),
"kpca__kernel":["rbf","sigmoid"]
}]

grid_search=GridSearchCV(clf,param_grid,cv=3)
grid_search.fit(X,y)
# Out:
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
# ...

# %%
grid_search.fit(iris.data, iris.target)
# Out:
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/grimstir/anaconda3/envs/pydev37/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
# ...

# %%
print(grid_search.best_params_)
# Out:
# {'kpca__gamma': 0.05, 'kpca__kernel': 'rbf'}
